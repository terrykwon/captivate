# %%
from unimodal import audial
import numpy as np
from visualization.visualizer import Visualizer

# %load_ext autoreload
# %autoreload 2

# %%
speech_recognizer = audial.SpeechRecognizer()
url = "rtmp://video:1935/captivate/test"

# %%
speech_recognizer.transcribe_stream(url)
# Out:
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript: 깍두기
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript: 깍두기가
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript: 깍두기 거는
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript: 깍두기가 나와
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript: 깍두기가 나왔어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  나왔어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  야 그거
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  야 그거 우리
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  야 그거 우리 집
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  야 그거 우리 집에
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  우리 집에
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 넣어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  넣어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  넣어 줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  넣어 주라
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  주라
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱이
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱이 너
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱이 넣어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱이 넣어 줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  넣어 줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  행동을 딱딱
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  행동을 딱딱이
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  행동을 딱딱이 집에
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱이 집에서
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에서
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 좀
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 좋은
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 좀 넣어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  좀 넣어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 넣어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  너 이게 뭐
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  너 이게 뭐야
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 너 이게
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  뭐야
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 너 이게 뭐야
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 너 이게 뭐야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  야 이거
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 너 이게 뭐야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  야 이게
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 너 이게 뭐야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  야 이게 뭐
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 너 이게 뭐야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  야 이게 뭐야
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 너 이게 뭐야 야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  이게 뭐야
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좀 너 이게 뭐야 야 이게
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  뭐야
# Finished: True
# Stability: 0.0
# Confidence: 0.8702199459075928
# Transcript: 깍두기가 나왔어 야 그거 우리 집에 넣어 주라 딱딱이 넣어 줘 행동을 딱딱이 집에 좋은 너 이게 뭐야 야 이게 뭐야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  닭갈비전
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱이 전화
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱이 전화
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱 딱딱
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱 딱딱이
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  딱딱이
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  이거 누구
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  이거 누구 꺼
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  이거 누구 거야
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  거야
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  이거
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  이거 우리
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  이거 우리 집
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  우리 집에
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  우리 집에서
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 또
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 똥
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 좀 넣어
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  집에 좀 넣어 줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  좀 넣어 줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어 줘
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  놓자 창문에 넣지
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  놓자 창문에서 차
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  놓자 창문에 넣자
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어 놓자
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  창문에 넣자
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어 놓자 창문에 넣자
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어 놓자
# Finished: False
# Stability: 0.009999999776482582
# Confidence: 0.0
# Transcript:  창문에서 차 창문에 넣어 보자
# Finished: False
# Stability: 0.8999999761581421
# Confidence: 0.0
# Transcript:  딱딱 딱딱이 이거 누구 거야 이거 우리 집에 좀 넣어 놓자 창문에서 차 창문에 넣어 보자
# end of audio stream
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d25ce7867683> in <module>
# ----> 1 speech_recognizer.transcribe_stream(url)
#
# /workspace/modelserver/src/unimodal/audial.py in transcribe_stream(self, url, queue, frame_size, sampling_rate, language_code)
#      48
#      49         # throws an error if don't send audio for a long time; should catch it
# ---> 50         for response in responses:
#      51             # Once the transcription has settled, the first result will contain the
#      52             # is_final result. The other results will be for subsequent portions of
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in next(self)
#      95                 del self._stored_first_result
#      96                 return result
# ---> 97             return six.next(self._wrapped)
#      98         except grpc.RpcError as exc:
#      99             # If the stream has already returned data, we cannot recover here.
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in __next__(self)
#     414
#     415     def __next__(self):
# --> 416         return self._next()
#     417
#     418     def _next(self):
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in _next(self)
#     695                      and self._state.code is not None))
#     696
# --> 697             _common.wait(self._state.condition.wait, _response_ready)
#     698             if self._state.response is not None:
#     699                 response = self._state.response
#
# /opt/conda/lib/python3.7/site-packages/grpc/_common.py in wait(wait_fn, wait_complete_fn, timeout, spin_cb)
#     136     if timeout is None:
#     137         while not wait_complete_fn():
# --> 138             _wait_once(wait_fn, MAXIMUM_WAIT_TIMEOUT, spin_cb)
#     139     else:
#     140         end = time.time() + timeout
#
# /opt/conda/lib/python3.7/site-packages/grpc/_common.py in _wait_once(wait_fn, timeout, spin_cb)
#     101
#     102 def _wait_once(wait_fn, timeout, spin_cb):
# --> 103     wait_fn(timeout=timeout)
#     104     if spin_cb is not None:
#     105         spin_cb()
#
# /opt/conda/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
visualizer = Visualizer()

import textwrap

def hex2color_int(h):
    return tuple(int(h[i:i+2], 16) for i in (1, 3, 5))

COLORS_HEX = {
    'white': '#ffffff',
    'lime': '#A0ED2F',
}

COLORS_RGB = {k:hex2color_int(v) for (k,v) in COLORS_HEX.items()}

caption = np.zeros((360, 1280, 3)).astype('uint8')
text = '위키백과는 자유 저작물을 보유하고 상업적인 광고가 없으며 주로 기부금을 통해 지원을 받는 비영리 단체인 위키미디어 재단에 의해 소유되고 지원을 받고 있다.[4][5][6][7] 2020년 기준으로 영어판 600만여 개, 한국어판 521,340개를 비롯하여 300여 언어판을 합하면 4천만 개 이상의 글이 수록되어 꾸준히 성장하고 있으며 앞으로 더 성장할 예정이다.'
wrapped = textwrap.wrap(text, width=40)
x = 20
y = 20
dy = 50

for line in wrapped:
    caption = visualizer.cv2_write_text(caption, line, (x, y), COLORS_RGB['lime'])
    y += dy

visualizer.imshow_as_jpeg(caption)
