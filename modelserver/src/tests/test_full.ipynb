# %%
import sys
sys.path.insert(0, '..')
# %cd ..


from modelserver import ModelServer
from visualization.visualizer import Visualizer
from unimodal.visual import VisualMonitor

import cv2
import numpy as np

# import torch
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2,3'

# %load_ext autoreload
# %autoreload 2
# Out:
# /workspace/modelserver/src
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/workspace/modelserver/default-demo-app-c4bc3-b67061a9c4b1.json'

# %%
url = "rtmp://video:1935/captivate/test"
modelserver = ModelServer(url)
modelserver.run(visualize=True)
# Out:
# Process Process-4:
# Process Process-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/workspace/modelserver/src/unimodal/audial.py", line 19, in run
#     speech_recognizer.transcribe_stream(url, queue)
#   File "/workspace/modelserver/src/unimodal/visual.py", line 22, in run
#     monitor.start(url, queue)
#   File "/workspace/modelserver/src/unimodal/audial.py", line 70, in transcribe_stream
#     for response in responses:
#   File "/workspace/modelserver/src/unimodal/visual.py", line 61, in start
#     results = self.predict_single_frame(frame)
#   File "/opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py", line 97, in next
#     return six.next(self._wrapped)
#   File "/workspace/modelserver/src/unimodal/visual.py", line 86, in predict_single_frame
#     objects = self.object_detector.predict(frame)
#   File "/opt/conda/lib/python3.7/site-packages/grpc/_channel.py", line 416, in __next__
#     return self._next()
#   File "/workspace/modelserver/src/base/object_detector.py", line 24, in predict
#     outputs = self.model(image)
#   File "/opt/conda/lib/python3.7/site-packages/grpc/_channel.py", line 697, in _next
#     _common.wait(self._state.condition.wait, _response_ready)
#   File "/opt/conda/lib/python3.7/site-packages/grpc/_common.py", line 138, in wait
#     _wait_once(wait_fn, MAXIMUM_WAIT_TIMEOUT, spin_cb)
#   File "/opt/conda/lib/python3.7/site-packages/detectron2/engine/defaults.py", line 219, in __call__
#     image = self.aug.get_transform(original_image).apply_image(original_image)
#   File "/opt/conda/lib/python3.7/site-packages/grpc/_common.py", line 103, in _wait_once
#     wait_fn(timeout=timeout)
#   File "/opt/conda/lib/python3.7/site-packages/detectron2/data/transforms/transform.py", line 122, in apply_image
#     pil_image = pil_image.resize((self.new_w, self.new_h), interp_method)
#   File "/opt/conda/lib/python3.7/threading.py", line 300, in wait
#     gotit = waiter.acquire(True, timeout)
#   File "/opt/conda/lib/python3.7/site-packages/PIL/Image.py", line 1929, in resize
#     return self._new(self.im.resize(size, resample, box))
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4646bdc0323e> in <module>
#       1 url = "rtmp://video:1935/captivate/test"
#       2 modelserver = ModelServer(url)
# ----> 3 modelserver.run(visualize=True)
#
# /workspace/modelserver/src/modelserver.py in run(self, visualize)
#     174         while (1):
#     175             # This blocks until an item is available
# --> 176             result = self.queue.get(block=True, timeout=None)
#     177
#     178             if result['from'] == 'image':
#
# /opt/conda/lib/python3.7/multiprocessing/queues.py in get(self, block, timeout)
#      92         if block and timeout is None:
#      93             with self._rlock:
# ---> 94                 res = self._recv_bytes()
#      95             self._sem.release()
#      96         else:
#
# /opt/conda/lib/python3.7/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# /opt/conda/lib/python3.7/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# /opt/conda/lib/python3.7/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:
