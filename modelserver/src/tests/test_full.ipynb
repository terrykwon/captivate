# %%
import sys
sys.path.insert(0, '..')
# %cd ..


from modelserver import ModelServer
from visualization.visualizer import Visualizer
from unimodal.visual import VisualMonitor

import cv2
import numpy as np

import torch
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '2,3'

# %load_ext autoreload
# %autoreload 2
# Out:
# /workspace/modelserver/src

# %%
url = "rtmp://video:1935/captivate/test"
modelserver = ModelServer(url)
modelserver.run(visualize=True)
# Out:
# Process Process-1:
# Process Process-2:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/workspace/modelserver/src/unimodal/visual.py", line 19, in run
#     monitor.start(url, queue)
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/workspace/modelserver/src/unimodal/visual.py", line 49, in start
#     results = self.predict_single_frame(frame)
#   File "/workspace/modelserver/src/unimodal/audial.py", line 18, in run
#     speech_recognizer.transcribe_stream(url, queue)
#   File "/workspace/modelserver/src/unimodal/visual.py", line 72, in predict_single_frame
#     face_bboxes = self.face_detector.predict(frame)
#   File "/workspace/modelserver/src/unimodal/audial.py", line 65, in transcribe_stream
#     for response in responses:
#   File "/workspace/modelserver/src/base/face_detector2.py", line 23, in predict
#     predictions, landmarks = self.model.detect(image, threshold=0.5, scale=1.0)
#   File "/opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py", line 97, in next
#     return six.next(self._wrapped)
#   File "/opt/conda/lib/python3.7/site-packages/insightface/model_zoo/face_detection.py", line 329, in detect
#     proposals = bbox_pred(anchors, bbox_deltas)
#   File "/opt/conda/lib/python3.7/site-packages/grpc/_channel.py", line 416, in __next__
#     return self._next()
#   File "/opt/conda/lib/python3.7/site-packages/insightface/model_zoo/face_detection.py", line 163, in bbox_pred
#     pred_ctr_y = dy * heights[:, np.newaxis] + ctr_y[:, np.newaxis]
#   File "/opt/conda/lib/python3.7/site-packages/grpc/_channel.py", line 697, in _next
#     _common.wait(self._state.condition.wait, _response_ready)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.7/site-packages/grpc/_common.py", line 138, in wait
#     _wait_once(wait_fn, MAXIMUM_WAIT_TIMEOUT, spin_cb)
#   File "/opt/conda/lib/python3.7/site-packages/grpc/_common.py", line 103, in _wait_once
#     wait_fn(timeout=timeout)
#   File "/opt/conda/lib/python3.7/threading.py", line 300, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4646bdc0323e> in <module>
#       1 url = "rtmp://video:1935/captivate/test"
#       2 modelserver = ModelServer(url)
# ----> 3 modelserver.run(visualize=True)
#
# /workspace/modelserver/src/modelserver.py in run(self, visualize)
#      77         while (1):
#      78             # check if something new appeared in queue
# ---> 79             if self.queue.empty():
#      80                 # sleep here?
#      81                 continue
#
# /opt/conda/lib/python3.7/multiprocessing/queues.py in empty(self)
#     118
#     119     def empty(self):
# --> 120         return not self._poll()
#     121
#     122     def full(self):
#
# /opt/conda/lib/python3.7/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /opt/conda/lib/python3.7/multiprocessing/connection.py in _poll(self, timeout)
#     412
#     413     def _poll(self, timeout):
# --> 414         r = wait([self], timeout)
#     415         return bool(r)
#     416
#
# /opt/conda/lib/python3.7/multiprocessing/connection.py in wait(object_list, timeout)
#     912         with _WaitSelector() as selector:
#     913             for obj in object_list:
# --> 914                 selector.register(obj, selectors.EVENT_READ)
#     915
#     916             if timeout is not None:
#
# /opt/conda/lib/python3.7/selectors.py in register(self, fileobj, events, data)
#     350
#     351     def register(self, fileobj, events, data=None):
# --> 352         key = super().register(fileobj, events, data)
#     353         poller_events = 0
#     354         if events & EVENT_READ:
#
# /opt/conda/lib/python3.7/selectors.py in register(self, fileobj, events, data)
#     236             raise ValueError("Invalid events: {!r}".format(events))
#     237
# --> 238         key = SelectorKey(fileobj, self._fileobj_lookup(fileobj), events, data)
#     239
#     240         if key.fd in self._fd_to_key:
#
# /opt/conda/lib/python3.7/selectors.py in _fileobj_lookup(self, fileobj)
#     223         """
#     224         try:
# --> 225             return _fileobj_to_fd(fileobj)
#     226         except ValueError:
#     227             # Do an exhaustive search.
#
# /opt/conda/lib/python3.7/selectors.py in _fileobj_to_fd(fileobj)
#      35     else:
#      36         try:
# ---> 37             fd = int(fileobj.fileno())
#      38         except (AttributeError, TypeError, ValueError):
#      39             raise ValueError("Invalid file object: "
#
# KeyboardInterrupt:
